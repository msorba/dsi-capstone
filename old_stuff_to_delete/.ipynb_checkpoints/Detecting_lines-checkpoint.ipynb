# %%
# Additional python packages
import os, urllib, io, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import PIL
from PIL import Image
import cv2
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN, SpectralClustering
from functions import *# Our functions

# %%
images = load_images('../Data/Keyence')
#image_data = get_data_from_filenames('../Data/Keyence')

# %% [markdown]
# ### Plot image

# %%
f, axarr = plt.subplots(5,4,figsize=(15,15))
k=0
for i in range(5):
    for j in range(4):
        axarr[i,j].imshow(images[k])
        k+=1
#plt.figure(num=None, figsize=(20, 20), dpi=80, facecolor='w', edgecolor='k')

# %% [markdown]
# ### Transform image to polar coordinates

# %% [markdown]
# We can see that the   “spokes” now appear to be horizontal lines when plotted using polar coordinates.

# %%
polar_images=[polar_coord(np.asarray(img)) for img in images]
f, axarr = plt.subplots(5,4,figsize=(15,15))
k=0
for i in range(5):
    for j in range(4):
        axarr[i,j].imshow(polar_images[k])
        k+=1

# %% [markdown]
# ##### Plot classes using get_wrinkle_class

# %%
img_classes=[get_classes(img,threshold_val=100,n_clusters=3)[1] for img in images]

f, axarr = plt.subplots(5,4,figsize=(15,15))
k=0
for i in range(5):
    for j in range(4):
        axarr[i,j].imshow(img_classes[k])
        k+=1
# Out:
# /Users/msorba/Documents/Columbia courses/DSI capstone/dsi-capstone/functions.py:175: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# /Users/msorba/Documents/Columbia courses/DSI capstone/dsi-capstone/functions.py:175: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /Users/msorba/Documents/Columbia courses/DSI capstone/dsi-capstone/functions.py:175: RuntimeWarning:
#
# invalid value encountered in less
#
# /Users/msorba/Documents/Columbia courses/DSI capstone/dsi-capstone/functions.py:175: RuntimeWarning:
#
# invalid value encountered in greater

# %% [markdown]
# ##### Plot wrinkle class using get_wrinkle_class

# %%
img_wrinkle_class=[get_wrinkle_class(img,threshold_val=80,n_clusters=6)[1] for img in images]
f, axarr = plt.subplots(5,4,figsize=(15,15))
k=0
for i in range(5):
    for j in range(4):
        axarr[i,j].imshow(img_wrinkle_class[k])
        k+=1
# Out:
# /Users/msorba/Documents/Columbia courses/DSI capstone/dsi-capstone/functions.py:175: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# /Users/msorba/Documents/Columbia courses/DSI capstone/dsi-capstone/functions.py:175: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /Users/msorba/Documents/Columbia courses/DSI capstone/dsi-capstone/functions.py:175: RuntimeWarning:
#
# invalid value encountered in less
#
# /Users/msorba/Documents/Columbia courses/DSI capstone/dsi-capstone/functions.py:175: RuntimeWarning:
#
# invalid value encountered in greater
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-56f9bb2f6cdf> in <module>()
# ----> 1 img_wrinkle_class=[get_wrinkle_class(img,threshold_val=80,n_clusters=6)[1] for img in images]
#       2 f, axarr = plt.subplots(5,4,figsize=(15,15))
#       3 k=0
#       4 for i in range(5):
#       5     for j in range(4):
#
# <ipython-input-6-56f9bb2f6cdf> in <listcomp>(.0)
# ----> 1 img_wrinkle_class=[get_wrinkle_class(img,threshold_val=80,n_clusters=6)[1] for img in images]
#       2 f, axarr = plt.subplots(5,4,figsize=(15,15))
#       3 k=0
#       4 for i in range(5):
#       5     for j in range(4):
#
# ~/Documents/Columbia courses/DSI capstone/dsi-capstone/functions.py in get_wrinkle_class(img, resize, n_clusters, threshold_val)
#     244         X         = np.reshape(img_array, (w*h,d))
#     245         df        = pd.DataFrame(X, columns=['red', 'green', 'blue'])
# --> 246         df_mean   = df.astype('int').groupby(labels).mean()
#     247
#     248         # Find most red class
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6657         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6658                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6659                        observed=observed, **kwargs)
#    6660
#    6661     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3313                         observed=observed,
#    3314                         in_axis=in_axis) \
# -> 3315             if not isinstance(gpr, Grouping) else gpr
#    3316
#    3317         groupings.append(ping)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis)
#    2942         self.name = name
#    2943         self.level = level
# -> 2944         self.grouper = _convert_grouper(index, grouper)
#    2945         self.all_grouper = None
#    2946         self.index = index
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _convert_grouper(axis, grouper)
#    3340     elif isinstance(grouper, (list, Series, Index, np.ndarray)):
#    3341         if len(grouper) != len(axis):
# -> 3342             raise ValueError('Grouper and axis must be same length')
#    3343         return grouper
#    3344     else:
#
# ValueError: Grouper and axis must be same length

# %% [markdown]
# ### Detect straight lines

# %%
img_lines=[detect_lines(img) for img in images]
f, axarr = plt.subplots(5,4,figsize=(15,15))
k=0
for i in range(5):
    for j in range(4):
        axarr[i,j].imshow(img_lines[k][0])
        k+=1
