# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from functions import * # Our functions 
import os
from sklearn.cluster import KMeans
from functions import detect_lines_cy

# %%
def reverse_from_linear_polarity(original_X, item_to_be_reversed):
    x, y, r = original_X.shape[0]/2, original_X.shape[1]/2, np.sqrt(((original_X.shape[0]/2.0)**2.0)+((original_X.shape[1]/2.0)**2.0))
    X_inverse = cv2.linearPolar(item_to_be_reversed, (x, y), r, cv2.WARP_INVERSE_MAP)
    return X_inverse

# %%
image_folder = os.getcwd()+'/static/uploads'

# %%
images = load_images(image_folder)

# %%
def find_circle(filename):
    image = cv2.imread(filename, 0)
    size = np.sqrt(image.size)
    output = image.copy()
    center_x, center_y = None, None
    circles = cv2.HoughCircles(image,cv2.HOUGH_GRADIENT,1,20,param1=50,param2=30,minRadius= int(size*5/12), maxRadius= int(size/2))
    if circles is not None:
        # convert the (x, y) coordinates and radius of the circles to integers
        circles = np.round(circles[0, :]).astype("int")

        # loop over the (x, y) coordinates and radius of the circles
        for (x, y, r) in circles:
            # draw the circle in the output image, then draw a rectangle
            # corresponding to the center of the circle
            if np.sqrt((x -size/2)**2+(y-size/2)**2) > (size / 8):
                continue
            center_x, center_y = x, y
            cv2.circle(output, (x, y), r, (0, 255, 0), 4)

            cv2.rectangle(output, (x - 5, y - 5), (x + 5, y + 5), (0, 128, 255), -1)
            break
        # show the output image
    if center_x == None:
        center_x = int(size/2)
        center_y = int(size/2)
            

        cv2.rectangle(output, (center_x - 5, center_y - 5), (center_x + 5, center_y + 5), (0, 128, 255), -1)
    return center_x, center_y

# %%
def polar_to_cartesian(ori_img, pol_img, pol_lines):
    import numpy as np
    row = len(pol_img)
    column = len(pol_img[0])
    t_pi = np.pi*2
    max_radius = np.sqrt(((ori_img.shape[0]/2.0)**2.0)+((ori_img.shape[1]/2.0)**2.0))
    Klin = column / max_radius
    Kangle = row / t_pi
    cart_lines = []
    for line in pol_lines:
        coords=line[0]
        rho_1, phi_1, rho_2, phi_2 = coords[0], coords[1], coords[2], coords[3]
        angleRad1 = phi_1 / Kangle
        magnitude1 = rho_1 / Klin
        x1 = magnitude1 * np.cos(angleRad1)
        y1 =  magnitude1 * np.sin(angleRad1)
        angleRad2 = phi_2 / Kangle
        magnitude2 = rho_2 / Klin
        x2 = magnitude2 * np.cos(angleRad2)
        y2 =  magnitude2 * np.sin(angleRad2)
        cart_lines.append([[int(x1 + ori_img.shape[0]/2), int(y1+ori_img.shape[1]/2),int(x2+ori_img.shape[0]/2), int(y2+ori_img.shape[1]/2)]])
    return cart_lines

# %%
def calculate_ratio(ori_img, cart_lines, center_x, center_y):
    original_image = ori_img.copy()
    threshold_size = np.sqrt(ori_img.size)/3
    for line in cart_lines:
        coords=line[0]
        dis = np.sqrt((np.asarray(center_x - coords[2])**2 + (center_y - coords[3]) **2))
            
        cv2.line(original_image,(coords[0],coords[1]),(coords[2],coords[3]),[255,255,255],3)
        cv2.line(original_image,(center_x,center_y),(coords[0],coords[1]),[0,255,0],3)
    return original_image

# %%
image_path = image_folder +'/' + 'sample.tif'
center_x, center_y = find_circle(image_path)
img = np.asarray(Image.open(image_path))
polar_img, reversed_lines = detect_lines_cy(img)
cart_lines = polar_to_cartesian(img, polar_img, reversed_lines)
final_image = calculate_ratio(img, cart_lines, center_x, center_y)
# Out:
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# /Users/Kiki/GitHub/dsi-capstone/functions.py:247: RuntimeWarning: divide by zero encountered in int_scalars
#   slope = (coords[3] - coords[1]) / (coords[2] - coords[0])

# %%
plt.imshow(np.hstack([final_image,polar_img]))

# %%
ratio_images= []
for filename in os.listdir(image_folder):
    print(filename)
    image_path = image_folder +'/' + filename
    
    center_x, center_y = find_circle(image_path)
    ori_img, pol_img, pol_lines = wrink_lines(image_path)[:3]
    if not pol_lines:
        ratio_images.append(None)
        continue
    print(pol_lines)
    cart_lines = polar_to_cartesian(ori_img, pol_img, pol_lines)
    ratio_image = calculate_ratio(ori_img, cart_lines, center_x, center_y)
    ratio_images.append(ratio_image)

# %%
plt.imshow(img_array)

# %%
cart_lines = polar_to_cartesian(ori_img, pol_img, pol_lines)
final_image = calculate_ratio(img_array, cart_lines, center_x, center_y)
plt.imshow(final_image)
cart_lines
# Out:
# []

# %%
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Out:
# phz_170809_D3.jpg
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in int_scalars
#   from ipykernel import kernelapp as app
# [array([[ 821,  226, 1050,  230]], dtype=int32), array([[634, 600, 933, 595]], dtype=int32), array([[499, 170, 748, 192]], dtype=int32)]
# phz_600_D4_B_2.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# scanner_sample1.jpg
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# phz_400_D5_B_1.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# WT_720_D5_B_2.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# WT_720_D4_B_4.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in int_scalars
#   from ipykernel import kernelapp as app
# WT_720_D5_B_4.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# WT_720_D4_B_3.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# WT_400_D4_B_2.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# phz_400_D4_B_1.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# phz_720_D4_B_1.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# [array([[ 22, 517, 408, 477]], dtype=int32)]
# WT_720_D4_B_2.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# WT_800_D4_B_4.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# phz_1200_D4_B_1.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# [array([[242, 870, 889, 825]], dtype=int32), array([[299, 638, 698, 632]], dtype=int32), array([[383, 861, 620, 865]], dtype=int32), array([[440, 795, 672, 799]], dtype=int32), array([[473, 891, 770, 927]], dtype=int32), array([[280, 816, 743, 807]], dtype=int32), array([[319, 812, 591, 807]], dtype=int32), array([[494, 869, 870, 843]], dtype=int32), array([[372, 826, 742, 814]], dtype=int32), array([[261, 794, 597, 794]], dtype=int32), array([[ 15, 841, 218, 848]], dtype=int32), array([[184, 855, 444, 846]], dtype=int32), array([[548, 873, 857, 867]], dtype=int32), array([[251, 764, 531, 784]], dtype=int32), array([[265, 748, 853, 769]], dtype=int32), array([[202, 857, 432, 853]], dtype=int32), array([[184, 899, 590, 828]], dtype=int32), array([[458, 795, 701, 795]], dtype=int32)]
# WT_800_D5_B_3.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# sample.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# WT_170725_D4.jpg
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in int_scalars
#   from ipykernel import kernelapp as app
# [array([[1558,  235, 1782,  199]], dtype=int32), array([[1753, 1142, 1970, 1181]], dtype=int32), array([[1753,  246, 1970,  211]], dtype=int32), array([[1736, 1224, 1968, 1179]], dtype=int32), array([[1539,  268, 1749,  228]], dtype=int32), array([[1556,  254, 1817,  204]], dtype=int32), array([[1573,  252, 1832,  207]], dtype=int32), array([[1576,  229, 1783,  218]], dtype=int32)]
# WT_170725_D5.jpg
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in int_scalars
#   from ipykernel import kernelapp as app
# [array([[1966,  276, 2182,  241]], dtype=int32), array([[111, 444, 432, 501]], dtype=int32), array([[1695,  281, 2007,  232]], dtype=int32), array([[ 413, 1515,  637, 1555]], dtype=int32), array([[1814,  283, 2053,  241]], dtype=int32), array([[1424, 1669, 1637, 1665]], dtype=int32), array([[1697,  294, 2026,  236]], dtype=int32), array([[1828,  262, 2032,  237]], dtype=int32), array([[1700,  294, 2028,  236]], dtype=int32)]
# WT_800_D4_B_3.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# phz_800_D4_B_2.tif
# /Users/Kiki/anaconda/envs/capstone/lib/python3.6/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# [array([[ 37, 274, 391, 274]], dtype=int32)]

# %%
ratio_images = [ratio_images[i] for i in range(len(ratio_images)) if type(ratio_images[i]) == np.ndarray]

# %%
for image in ratio_images:
    plt.figure()
    plt.imshow(image)

# %%
+row = len(polar_img_wrinkle)
column = len(polar_img_wrinkle[0])
t_pi = np.pi*2
max_radius = 1227.5179224760834
Klin = column / max_radius
Kangle = row / t_pi

# %%
cart_lines = []
for line in reserved_lines:
    
    coords=line[0]
    rho_1, phi_1, rho_2, phi_2 = coords[0], coords[1], coords[2], coords[3]
    angleRad1 = phi_1 / Kangle
    magnitude1 = rho_1 / Klin
    x1 = magnitude1 * np.cos(angleRad1)
    y1 =  magnitude1 * np.sin(angleRad1)
    angleRad2 = phi_2 / Kangle
    magnitude2 = rho_2 / Klin
    x2 = magnitude2 * np.cos(angleRad2)
    y2 =  magnitude2 * np.sin(angleRad2)
    cart_lines.append([[int(x1+847.5), int(y1+888.0),int(x2+847.5), int(y2+888.0)]])

# %%
original_image = img_array.copy()
threshold_size = np.sqrt(image.size)/3
for line in cart_lines:
    coords=line[0]
    dis = np.sqrt((center_x - coords[2])**2 + (center_y - coords[3]) **2)
    if dis > threshold_size:
        cv2.line(original_image,(coords[0],coords[1]),(coords[2],coords[3]),[255,255,255],3)
        cv2.line(original_image,(center_x,center_y),(coords[0],coords[1]),[0,255,0],3)
plt.imshow(original_image)
