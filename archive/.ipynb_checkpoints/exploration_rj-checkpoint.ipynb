# %% [markdown]
# # Capstone exploration

# %% [markdown]
# ## Ideas not implimented
#
# - Add position as a feature
# - Color the spoke type wrinkles and dense wrinkles as two seperate classes
# - Run this model on video so you can play a video of the wrinkle only
# - Could plot % wrinkle by type over time.
# - Calculate distribution of how close wrinkles are to center

# %%
# Additional python packages
import os, urllib, io, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN, SpectralClustering
import scipy.misc
from ggplot import *
import time
from sklearn.manifold import TSNE

from functions import * # Our functions

init_notebook_mode(connected=True)
# Out:
# /home/jupyter/.local/lib/python3.5/site-packages/ggplot/utils.py:81: FutureWarning:
#
# pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ## Load images and meta data

# %%
images=[]
names=[]
for root, dirs, files in os.walk('final_dataset'):
    for name in files:
        mypath = os.path.join(root,name)
        img=Image.open(mypath)
        arr = np.array(img).astype('uint8')
        images.append(arr)
        img.close()
        names.append(name.split('.')[0])

gene=[name.split('_')[0] for name in names]
days=[int(name.split('_')[1]) for name in names]
biofilm_number=[name.split('_')[2] for name in names]
dic={'label':names,'gene':gene,'days':days,'biofilm_number':biofilm_number}

df_all=pd.DataFrame.from_dict(dic)

# %% [markdown]
# ## Lets look at some of the images

# %%
fig = plt.figure(figsize=(15,15))
n = 4

for i,s in enumerate(images):
    try:
        fig.add_subplot(n,n,i+1)
        plt.imshow(s)
        title = 'gene: %s | day %d' %(df_all['gene'][i],df_all['days'][i])
        plt.title(title)
    except:
        pass
plt.show()

# %% [markdown]
# ### Process Images to find Wrinkles

# %%
img_classes=[get_classes(img,threshold_val=0, resize=128, n_clusters=2)[1] for img in images]
perc_wrink = [round(np.count_nonzero(img)/(128**2),2) for img in img_classes]
df_all['perc_wrink'] = perc_wrink
# Out:
# /home/jupyter/dsi-capstone/functions.py:177: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# /home/jupyter/dsi-capstone/functions.py:177: RuntimeWarning:
#
# invalid value encountered in multiply
#
# /home/jupyter/dsi-capstone/functions.py:175: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /home/jupyter/dsi-capstone/functions.py:175: RuntimeWarning:
#
# invalid value encountered in less
#
# /home/jupyter/dsi-capstone/functions.py:175: RuntimeWarning:
#
# invalid value encountered in greater
#
# /home/jupyter/dsi-capstone/functions.py:175: RuntimeWarning:
#
# divide by zero encountered in true_divide

# %% [markdown]
# ### Plots of processed images

# %%
fig = plt.figure(figsize=(15,15))
n = 5

for i,s in enumerate(img_classes):
    try:
        fig.add_subplot(n,n,i+1)
        plt.imshow(s, cmap='binary')
        title = '%s | %d | %f ' %(df_all['gene'][i],df_all['days'][i],df_all['perc_wrink'][i])
        plt.title(title)
    except:
        pass
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:395: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:396: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:403: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py:408: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:902: UserWarning:
#
# Warning: converting a masked element to nan.
#
# /usr/local/lib/python3.5/site-packages/numpy/ma/core.py:715: UserWarning:
#
# Warning: converting a masked element to nan.

# %% [markdown]
# ## Pre-process images for tSNE analysis

# %% [markdown]
# ### We filter images that have wrinkle percent less than 2%. This mostly eliminates all biofilms that are 1 and 2 days old.

# %%
tsne_data = []
tsne_info = pd.DataFrame(columns=df_all.columns)
for i,img in enumerate(img_classes):
    if perc_wrink[i] > .02 and perc_wrink[i] < 1.0:
        tsne_data.append(img)
        tsne_info = tsne_info.append(df_all.iloc[[i]])
#         t_img = Image.fromarray(img)
#         t_img = t_img.convert('RGB')
#         t_img.save('tsne_dataset/'+img_names[i-1])

# %%
# X = [x[:,:,0] for x in X]
X = [x.flatten() for x in tsne_data]
X = np.asarray(X)

# %%
labels = tsne_info['gene'].unique()
tsne_info['y'] = [int(np.where(labels==s)[0]) for s in tsne_info['gene']]
y = np.array(tsne_info['y'])

# %%
feat_cols = [ 'pixel'+str(i) for i in range(X.shape[1]) ]

df = pd.DataFrame(X,columns=feat_cols)
df['label'] = df_all['gene']
df['label'] = df['label'].apply(lambda i: str(i))

X, y = None, None


print('Size of the dataframe: {}'.format(df.shape))
# Out:
# Size of the dataframe: (526, 16385)

# %%
rndperm[:4]
# Out:
# array([131, 171,  50, 159])

# %%
rndperm = np.random.permutation(df.shape[0])

n_sne = 7000

time_start = time.time()
tsne = TSNE(n_components=3, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(df.loc[rndperm[:n_sne],feat_cols].values)

print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 526 samples in 0.294s...
# [t-SNE] Computed neighbors for 526 samples in 9.189s...
# [t-SNE] Computed conditional probabilities for sample 526 / 526
# [t-SNE] Mean sigma: 1519.781070
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 187.676300
# [t-SNE] Error after 300 iterations: 7.377076
# t-SNE done! Time elapsed: 19.440969705581665 seconds

# %%
np.savetxt("tsne_test.csv", tsne_results, delimiter="\t")
# np.savetxt("tsne_labels.tsv",np.array(df['label']))

# %%
a = np.array(df['label'])

# %%
df['label'].to_csv("tsne_labels.csv")

# %%
df_tsne = df.loc[rndperm[:n_sne],:].copy()
df_tsne['x-tsne'] = tsne_results[:,0]
df_tsne['y-tsne'] = tsne_results[:,1]

# %%
p = ggplot( df_tsne, aes(x='x-tsne', y='y-tsne', color='label') ) \
        + geom_point(size=70,alpha=0.6) \
        + ggtitle("tSNE dimensions colored by gene")\
        + xlim(-50,50) \
        + ylim(-50,50) \
        + theme_bw()

# %%
p
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# <ggplot: (8771433239798)>
